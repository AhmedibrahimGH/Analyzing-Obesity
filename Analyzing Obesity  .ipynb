# %% [markdown]
# ### Import Necessary Dependencies

# %%
import pandas as pd
import os
import seaborn as sns

# %%
# Here we will Load and Access the Data set file

Reading_Data_Set = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')

# %% [markdown]
# ### We Will now Explore Data Set

# %%
# Diplay / Showing Rows
print(Reading_Data_Set.head())

# Diplaying information about the Data set

print(Reading_Data_Set.info())

# Showing Statistics of Column of Data set
print(Reading_Data_Set.describe())

# This will show the Number of Rows And Columb in the Data Set
print (Reading_Data_Set.shape)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %% [markdown]
# ### Checking Missing values if Any

# %%
print(Reading_Data_Set.isnull().sum())
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# ### Here We will Check the balance of categorical Varaibles

# %%
for column_DataSet in Reading_Data_Set.select_dtypes(include=['object']).columns:
    print("Column Frequency Counts: " , '\n' , column_DataSet)
    # Here This Will Return Column Frequency Counts in Each Column
    print(Reading_Data_Set[column_DataSet].value_counts())
# Out:
# Column Frequency Counts:
#  Gender
# Gender
# Male      1068
# Female    1043
# Name: count, dtype: int64
# Column Frequency Counts:
#  family_history_with_overweight
# family_history_with_overweight
# yes    1726
# no      385
# Name: count, dtype: int64
# Column Frequency Counts:
#  FAVC
# FAVC
# yes    1866
# no      245
# Name: count, dtype: int64
# Column Frequency Counts:
#  CAEC
# CAEC
# Sometimes     1765
# Frequently     242
# Always          53
# no              51
# Name: count, dtype: int64
# Column Frequency Counts:
#  SMOKE
# SMOKE
# no     2067
# yes      44
# Name: count, dtype: int64
# Column Frequency Counts:
#  SCC
# SCC
# no     2015
# yes      96
# Name: count, dtype: int64
# Column Frequency Counts:
#  CALC
# CALC
# Sometimes     1401
# no             639
# Frequently      70
# Always           1
# Name: count, dtype: int64
# Column Frequency Counts:
#  MTRANS
# MTRANS
# Public_Transportation    1580
# Automobile                457
# ...

# %% [markdown]
# ### Here We will Check For Duplicates in our Data Set

# %%
# Check For Duplicates in our Data Set
Check_The_Duplicate_In_Data_Set = Reading_Data_Set.duplicated().sum()
print("\nNumber of duplicate entries: ", Check_The_Duplicate_In_Data_Set)
# Out:
# Number of duplicate entries:  24

# %% [markdown]
# ### Here We will Check For Consistency in our Data Set

# %%
print("Check Values of height outside the expected range => (1.5m - 2.5m): ", Reading_Data_Set[(Reading_Data_Set['Height'] < 1.5) | (Reading_Data_Set['Height'] > 2.5)].shape[0])
print("Check Values of weight outside the expected range => (60kg - 250kg): ", Reading_Data_Set[(Reading_Data_Set['Weight'] < 60) | (Reading_Data_Set['Weight'] > 150)].shape[0])
# Out:
# Check Values of height outside the expected range => (1.5m - 2.5m):  9
# Check Values of weight outside the expected range => (60kg - 250kg):  405

# %% [markdown]
# ### Here We will Check For Outliers in our Data Set

# %%
# Loop over numerical columns and create boxplots
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=df[column])  # Use 'x' as the parameter to specify the column for boxplot
    plt.title(f"Boxplot of {column}")
    plt.show()
